# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.read_csv('claudia.csv')
# Out:
#       'Time' 'VidTime'  'Signal Level'  'Blink'  'Attention'  'Meditation'  \
# 0    07:35.0   00:00.0             100        2           51            47
# 1    07:36.0   00:00.0             100        2           51            54
# 2    07:37.0   00:00.0             100        1           60            48
# 3    07:38.0   00:00.0             100        2           64            48
# 4    07:39.0   00:00.0             100        3           75            53
# 5    07:40.0   00:00.0             100        2           80            53
# 6    07:41.0   00:00.0             100        2           84            53
# 7    07:42.0   00:00.0             100        2           84            56
# 8    07:43.0   00:00.0             100        3           69            44
# 9    07:44.0   00:00.0              87        2           69            44
# 10   07:45.0   00:00.0             100        2           69            30
# ...
